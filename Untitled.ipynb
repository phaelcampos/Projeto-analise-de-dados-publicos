# %%
import pandas as pd
import seaborn as sb
import plotly.offline as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt 
py.init_notebook_mode(connected=True)
low_memory=False
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.read_csv('doacao.sangue1.csv', sep=',', header=2)
df=df.drop('Unnamed: 0',1)
df.set_index('ESTADO', inplace=True)

# %%
df
# Out:
#          ANO        MÊS  Mêsn  COMPARECIMENTO  BOLSAS DE SANGUE
# ESTADO
# AC      2016   Dezembro    12          1159.0               844
# AC      2016      Junho     6          1278.0               976
# AC      2016    Outubro    10          1314.0               998
# AC      2016   Setembro     9          1316.0              1010
# AC      2016  Fevereiro     2          1343.0               951
# AC      2016      marco     3          1365.0               990
# AC      2016      Julho     7          1367.0              1057
# AC      2016      Abril     4          1450.0              1065
# AC      2016   Novembro    11          1470.0              1062
# AC      2016     Agosto     8          1542.0              1152
# AC      2016    Janeiro     1          1571.0              1146
# AC      2016       Maio     5          1804.0              1308
# AC      2017      Abril     4          1067.0               807
# AC      2017      Junho     6          1089.0               815
# AC      2017  Fevereiro     2          1127.0               891
# AC      2017    Janeiro     1          1202.0               947
# AC      2017      marco     3          1316.0               969
# AC      2017     Agosto     8          1323.0              1023
# AC      2017      Julho     7          1564.0               108
# AC      2017       Maio     5          1597.0              1190
# AC      2017      TOTAL     0         10285.0              6750
# AC      2016      TOTAL     0         16979.0             12559
# AL      2016   Dezembro    12          2060.0              1344
# AL      2016      marco     3          2125.0              1291
# AL      2016  Fevereiro     2          2129.0              1441
# AL      2016    Janeiro     1          2156.0              1398
# AL      2016     Agosto     8          2196.0              1367
# AL      2016      Julho     7          2262.0              1463
# AL      2016   Novembro    11          2336.0              1624
# AL      2016    Outubro    10          2413.0              1224
# ...      ...        ...   ...             ...               ...
# SJRP    2017  Fevereiro     2          3281.0              2680
# SJRP    2017      marco     3          3615.0              2954
# SJRP    2017      Abril     4          4241.0              3473
# SJRP    2017       Maio     5          3324.0              2793
# SJRP    2017      Junho     6          4271.0              3355
# SJRP    2017      Julho     7          3757.0              3079
# SJRP    2017     Agosto     8          3249.0              2722
# SJRP    2017      Total     0         29000.0             23784
# TO      2016    Janeiro     1             NaN              1417
# TO      2016  Fevereiro     2             NaN              2157
# TO      2016      marco     3             NaN              1825
# TO      2016      Abril     4             NaN              1782
# TO      2016       Maio     5             NaN              2003
# TO      2016      Junho     6             NaN              2119
# TO      2016      Julho     7             NaN              1609
# TO      2016     Agosto     8             NaN              1913
# TO      2016   Setembro     9             NaN              1401
# TO      2016    Outubro    10             NaN              1982
# TO      2016   Novembro    11             NaN              1846
# TO      2016   Dezembro    12             NaN              2130
# TO      2016      Total     0             NaN             22184
# TO      2017    Janeiro     1             NaN              1684
# TO      2017  Fevereiro     2             NaN              2473
# TO      2017      marco     3             NaN              1918
# TO      2017      Abril     4             NaN              1986
# TO      2017       Maio     5             NaN              1895
# TO      2017      Junho     6             NaN              1998
# TO      2017      Julho     7             NaN              2034
# TO      2017     Agosto     8             NaN              1935
# TO      2017      Total     0             NaN             15923
#
# [704 rows x 5 columns]

# %%
df.query('MÊS=="Total" and ANO==2017')[['BOLSAS DE SANGUE','COMPARECIMENTO']].plot.bar()

# %%
df.query('MÊS=="Total" and ANO==2016')[['BOLSAS DE SANGUE','COMPARECIMENTO']].plot.bar()
